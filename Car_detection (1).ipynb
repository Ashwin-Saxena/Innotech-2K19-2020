# %%
import cv2
import numpy as np
import time
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
red = mpimg.imread('red.jpg')
green = mpimg.imread('green.jpg')
# print(img)
# imgplot = plt.imshow(red)

# %%
cam=cv2.VideoCapture("video.avi")
cam1=cv2.VideoCapture("videoplayback.mp4")

# %%
car_cascade = cv2.CascadeClassifier('cars.xml')

# %%
font                   = cv2.FONT_HERSHEY_SIMPLEX
bottomLeftCornerOfText = (10,500)
fontScale              = 1
fontColor              = ("0,0,255")
lineType               = 2

# %%
value="0"
value1="0"
f, axarr = plt.subplots(2,2)
# for i in range(0,1100):
while True:
#     time.sleep(2)
#     value=10
   
    ret ,frame=cam.read()
    ret1 , frame1=cam1.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray1=cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    cars = car_cascade.detectMultiScale(gray, 1.1, 1) 
    for (x,y,w,h) in cars: 
        jk=int(value)+1
        value=str(jk)
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2) 
        cv2.putText(frame,value,(14,25), font, .5,(0,35,255),2,cv2.LINE_AA)   
    cv2.imshow('Detecting Traffic for Phase A', frame) 
    
    cars = car_cascade.detectMultiScale(gray1, 1.1, 1) 
    for (x,y,w,h) in cars: 
        jk1=int(value1)+1
        value1=str(jk1)
        cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,0,255),2) 
        cv2.putText(frame1,value1,(14,25), font, .5,(0,35,255),2,cv2.LINE_AA)   
    cv2.imshow('Detecting Traffic for second side', frame1) 
    # Wait for Esc key to stop 
    if cv2.waitKey(33) == 27: 
        break

cv2.destroyAllWindows()
print("Traffic Density as per No. of cars Detected as per squares created  for First:",value)
print("Traffic Density as per No. of cars Detected as per squares created  for Second:",value1)
time.sleep(2)
if value>value1:
    print("Side 1 Needs More Time \n ")
    axarr[0,0].imshow(green)
    print("Path 1: \t\t Path 2 :")
    axarr[0,1].imshow(red)
else :
    print("Side 2 Needs More Time")
    print("Path 1: \t\t Path 2 :")
    axarr[0,0].imshow(red)
    axarr[0,1].imshow(green)
# Out:
# Traffic Density as per No. of cars Detected as per squares created  for First: 40
# Traffic Density as per No. of cars Detected as per squares created  for Second: 0
# Side 1 Needs More Time
#
# Path 1: 		 Path 2 :

# %%
def function(val):
    value="0"
    value1="0"
    jk=0
    jk1=0
    f, axarr = plt.subplots(2,2)
    while True:
        #     time.sleep(2)
        #     value=10
        ret ,frame=cam.read()
        ret1 , frame1=cam1.read()
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        gray1=cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
        cars = car_cascade.detectMultiScale(gray, 1.1, 1) 
        for (x,y,w,h) in cars: 
            jk=int(value)+1
            value=str(jk)
            cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2) 
            cv2.putText(frame,value,(14,25), font, .5,(0,35,255),2,cv2.LINE_AA)   
        cv2.imshow('Detecting Traffic for Phase A', frame) 
        cars = car_cascade.detectMultiScale(gray1, 1.1, 1) 
        for (x,y,w,h) in cars: 
            jk1=int(value1)+1
            value1=str(jk1)
            cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,0,255),2) 
            cv2.putText(frame1,value1,(14,25), font, .5,(0,35,255),2,cv2.LINE_AA)   
        cv2.imshow('Detecting Traffic for second side', frame1) 
        # Wait for Esc key to stop 
        if cv2.waitKey(33) == 27: 
            break
    cv2.destroyAllWindows()
    print("Traffic Density as per No. of cars Detected as per squares created  for First:",value)
    print("Traffic Density as per No. of cars Detected as per squares created  for Second:",value1)
    time.sleep(2)
    if value>value1:
        print("Side 1 Needs More Time \n ")
        axarr[0,0].imshow(green)
        sle_ti=int(value)/100
        print("Path 1: \t\t Path 2 :")
        print(sle_ti,"\t\t\t",sle_ti)
        axarr[0,1].imshow(red)
    else :
        print("Side 2 Needs More Time")
        sle_ti=int(value1)/100
        print("Path 1: \t\t Path 2 :")
        print(sle_ti,"\t\t\t",sle_ti)
        axarr[0,0].imshow(red)
        axarr[0,1].imshow(green)
    time.sleep(sle_ti)
    if val<4:
        val=val+1
        function(val)
function(1)
# Out:
# Traffic Density as per No. of cars Detected as per squares created  for First: 71
# Traffic Density as per No. of cars Detected as per squares created  for Second: 0
# Side 1 Needs More Time
#
# Path 1: 		 Path 2 :
# 0.71 			 0.71
# Traffic Density as per No. of cars Detected as per squares created  for First: 150
# Traffic Density as per No. of cars Detected as per squares created  for Second: 0
# Side 1 Needs More Time
#
# Path 1: 		 Path 2 :
# 1.5 			 1.5
# Traffic Density as per No. of cars Detected as per squares created  for First: 478
# Traffic Density as per No. of cars Detected as per squares created  for Second: 615
# Side 2 Needs More Time
# Path 1: 		 Path 2 :
# 6.15 			 6.15
# Traffic Density as per No. of cars Detected as per squares created  for First: 133
# Traffic Density as per No. of cars Detected as per squares created  for Second: 342
# Side 2 Needs More Time
# Path 1: 		 Path 2 :
# 3.42 			 3.42
